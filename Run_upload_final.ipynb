# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.manifold import TSNE
import pickle
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
#%matplotlib qt
import csv
from sklearn.metrics import f1_score
import lightgbm as lgb
import itertools
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_9.4.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    #else:
        #print('Confusion matrix, without normalization')
    #print(cm)
    #plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

def lgb_f1_score(y_hat, data):
    y_true = data.get_label()
    y_hat = np.round(y_hat) # scikits f1 doesn't like probabilities
    return 'f1', f1_score(y_true, y_hat), True

# %%
# features, labels and control submission
label_train = np.load("data/train_label.npy")
features_train = np.load("data/all_features_train.npy")
features_test = np.load("data/all_features_test.npy")
print(features_train.shape)
print(features_test.shape)
# Out:
# (38289, 1366)
# (37439, 1366)

# %% [markdown]
# # Correlated features

# %%
corrcoef_matrix = np.corrcoef(features_train, rowvar=False)
corrcoef_matrix.shape
corrcoef_matrix = np.triu(corrcoef_matrix)

# %%
plt.imshow(abs(corrcoef_matrix))
plt.colorbar()

# %%
indx = np.argwhere(corrcoef_matrix > 0.9)



df = pd.DataFrame(indx, columns=['one', 'two'])
df = df[(df.one != df.two )]

# %%
df
# Out:
#         one   two
# 1         0     7
# 2         0    14
# 3         0    21
# 4         0    28
# 5         0    35
# 6         0    42
# 7         0    49
# 8         0    56
# 9         0    63
# 10        0    70
# 11        0    77
# 12        0    84
# 13        0    91
# 14        0    98
# 15        0   105
# 16        0   112
# 17        0   119
# 19        1     8
# 20        1    15
# 21        1    22
# 22        1    29
# 23        1    36
# 24        1    43
# 25        1    50
# 26        1    57
# 27        1    64
# 28        1    71
# 29        1    78
# 30        1    85
# 31        1    92
# ...     ...   ...
# 23596  1328  1334
# 23597  1328  1340
# 23600  1330  1336
# 23602  1331  1337
# 23604  1332  1335
# 23607  1334  1340
# 23612  1338  1341
# 23619  1344  1346
# 23620  1344  1347
# 23623  1346  1347
# 23624  1346  1352
# 23627  1348  1354
# 23629  1349  1352
# 23630  1349  1355
# 23632  1350  1353
# 23635  1352  1358
# 23636  1352  1364
# 23639  1354  1360
# 23641  1355  1358
# 23642  1355  1361
# 23643  1355  1364
# 23645  1356  1359
# 23646  1356  1362
# 23647  1356  1365
# 23650  1358  1361
# 23651  1358  1364
# 23653  1359  1362
# 23654  1359  1365
# 23657  1361  1364
# 23659  1362  1365
#
# [22297 rows x 2 columns]

# %%
keep = [0]
for i =
# Out:
#   File "<ipython-input-80-bf02276facf6>", line 2
#     for i =
#           ^
# SyntaxError: invalid syntax

# %%
for idx, val in enumerate(indx):
    print(idx)
    if val[0]!=val[1]:
        doit = True
        for k in stay:
            if np.array_equal(np.array([val[1],val[0]]),k):
                doit=False
        if doit:
            stay.append(val)

# %%
stay

# %%
corrvariable = []
for i in range(1366):
    A = corrcoef_matrix[:,i]
    A = np.delete(A,i)
    B = max(A)
    indB = np.argmax(A)
    corrvariable.append(B)

# %%
plt.plot(corrvariable, '.')

# %%
df = pd.DataFrame(features_train)

c = df.corr().abs()

s = c.unstack()
so = s.sort_values(kind="quicksort")

# %% [markdown]
# # Train and validation set, and predict

# %%
X_train, X_test, y_train, y_test = train_test_split(features_train, label_train, test_size=0.0005, random_state=42)

# %%
model = lgb.LGBMClassifier(objective='binary', reg_lambda=1,n_estimators=10000)

# %%
model.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=50, verbose=2)
# Out:
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's multi_logloss: 1.41391
# [4]	valid_0's multi_logloss: 1.28705
# [6]	valid_0's multi_logloss: 1.17159
# [8]	valid_0's multi_logloss: 1.08825
# [10]	valid_0's multi_logloss: 1.01733
# [12]	valid_0's multi_logloss: 0.957486
# [14]	valid_0's multi_logloss: 0.909057
# [16]	valid_0's multi_logloss: 0.87194
# [18]	valid_0's multi_logloss: 0.839843
# [20]	valid_0's multi_logloss: 0.809404
# [22]	valid_0's multi_logloss: 0.776153
# [24]	valid_0's multi_logloss: 0.748767
# [26]	valid_0's multi_logloss: 0.727366
# [28]	valid_0's multi_logloss: 0.709147
# [30]	valid_0's multi_logloss: 0.692383
# [32]	valid_0's multi_logloss: 0.676186
# [34]	valid_0's multi_logloss: 0.661661
# [36]	valid_0's multi_logloss: 0.654776
# [38]	valid_0's multi_logloss: 0.64041
# [40]	valid_0's multi_logloss: 0.628934
# [42]	valid_0's multi_logloss: 0.624961
# [44]	valid_0's multi_logloss: 0.620308
# [46]	valid_0's multi_logloss: 0.6178
# [48]	valid_0's multi_logloss: 0.610388
# [50]	valid_0's multi_logloss: 0.60407
# [52]	valid_0's multi_logloss: 0.599256
# [54]	valid_0's multi_logloss: 0.5842
# [56]	valid_0's multi_logloss: 0.577743
# [58]	valid_0's multi_logloss: 0.572463
# [60]	valid_0's multi_logloss: 0.558435
# [62]	valid_0's multi_logloss: 0.555784
# [64]	valid_0's multi_logloss: 0.55529
# [66]	valid_0's multi_logloss: 0.546885
# [68]	valid_0's multi_logloss: 0.539161
# [70]	valid_0's multi_logloss: 0.531385
# [72]	valid_0's multi_logloss: 0.522306
# [74]	valid_0's multi_logloss: 0.518686
# [76]	valid_0's multi_logloss: 0.50936
# [78]	valid_0's multi_logloss: 0.507599
# [80]	valid_0's multi_logloss: 0.502976
# [82]	valid_0's multi_logloss: 0.499221
# [84]	valid_0's multi_logloss: 0.494966
# [86]	valid_0's multi_logloss: 0.493967
# [88]	valid_0's multi_logloss: 0.493314
# [90]	valid_0's multi_logloss: 0.488788
# [92]	valid_0's multi_logloss: 0.484958
# [94]	valid_0's multi_logloss: 0.483049
# [96]	valid_0's multi_logloss: 0.482691
# [98]	valid_0's multi_logloss: 0.481443
# [100]	valid_0's multi_logloss: 0.472639
# [102]	valid_0's multi_logloss: 0.473323
# [104]	valid_0's multi_logloss: 0.472193
# [106]	valid_0's multi_logloss: 0.467958
# [108]	valid_0's multi_logloss: 0.465394
# [110]	valid_0's multi_logloss: 0.466611
# [112]	valid_0's multi_logloss: 0.463261
# [114]	valid_0's multi_logloss: 0.461731
# [116]	valid_0's multi_logloss: 0.462508
# [118]	valid_0's multi_logloss: 0.459533
# [120]	valid_0's multi_logloss: 0.459032
# [122]	valid_0's multi_logloss: 0.457584
# [124]	valid_0's multi_logloss: 0.458001
# [126]	valid_0's multi_logloss: 0.457152
# [128]	valid_0's multi_logloss: 0.455444
# [130]	valid_0's multi_logloss: 0.4523
# [132]	valid_0's multi_logloss: 0.452554
# [134]	valid_0's multi_logloss: 0.4465
# [136]	valid_0's multi_logloss: 0.444384
# [138]	valid_0's multi_logloss: 0.441566
# [140]	valid_0's multi_logloss: 0.441537
# [142]	valid_0's multi_logloss: 0.437487
# [144]	valid_0's multi_logloss: 0.43466
# [146]	valid_0's multi_logloss: 0.434242
# [148]	valid_0's multi_logloss: 0.435795
# [150]	valid_0's multi_logloss: 0.438058
# [152]	valid_0's multi_logloss: 0.432346
# [154]	valid_0's multi_logloss: 0.43304
# [156]	valid_0's multi_logloss: 0.431941
# [158]	valid_0's multi_logloss: 0.430937
# [160]	valid_0's multi_logloss: 0.428307
# [162]	valid_0's multi_logloss: 0.426239
# [164]	valid_0's multi_logloss: 0.421265
# [166]	valid_0's multi_logloss: 0.420566
# [168]	valid_0's multi_logloss: 0.417808
# [170]	valid_0's multi_logloss: 0.415189
# [172]	valid_0's multi_logloss: 0.414834
# [174]	valid_0's multi_logloss: 0.414661
# [176]	valid_0's multi_logloss: 0.414344
# [178]	valid_0's multi_logloss: 0.416986
# [180]	valid_0's multi_logloss: 0.417321
# [182]	valid_0's multi_logloss: 0.416272
# [184]	valid_0's multi_logloss: 0.417042
# [186]	valid_0's multi_logloss: 0.410909
# [188]	valid_0's multi_logloss: 0.41008
# [190]	valid_0's multi_logloss: 0.413315
# [192]	valid_0's multi_logloss: 0.412992
# [194]	valid_0's multi_logloss: 0.411454
# [196]	valid_0's multi_logloss: 0.410105
# [198]	valid_0's multi_logloss: 0.4096
# [200]	valid_0's multi_logloss: 0.412008
# [202]	valid_0's multi_logloss: 0.405681
# [204]	valid_0's multi_logloss: 0.404234
# [206]	valid_0's multi_logloss: 0.40306
# [208]	valid_0's multi_logloss: 0.401716
# [210]	valid_0's multi_logloss: 0.402739
# [212]	valid_0's multi_logloss: 0.399115
# [214]	valid_0's multi_logloss: 0.3975
# [216]	valid_0's multi_logloss: 0.396476
# [218]	valid_0's multi_logloss: 0.397087
# [220]	valid_0's multi_logloss: 0.396766
# [222]	valid_0's multi_logloss: 0.39679
# [224]	valid_0's multi_logloss: 0.395602
# [226]	valid_0's multi_logloss: 0.39723
# [228]	valid_0's multi_logloss: 0.399448
# [230]	valid_0's multi_logloss: 0.400531
# [232]	valid_0's multi_logloss: 0.400624
# [234]	valid_0's multi_logloss: 0.398344
# [236]	valid_0's multi_logloss: 0.399367
# [238]	valid_0's multi_logloss: 0.399692
# [240]	valid_0's multi_logloss: 0.399238
# [242]	valid_0's multi_logloss: 0.399207
# [244]	valid_0's multi_logloss: 0.398767
# [246]	valid_0's multi_logloss: 0.397998
# [248]	valid_0's multi_logloss: 0.394377
# [250]	valid_0's multi_logloss: 0.395747
# [252]	valid_0's multi_logloss: 0.393075
# [254]	valid_0's multi_logloss: 0.392287
# [256]	valid_0's multi_logloss: 0.3892
# [258]	valid_0's multi_logloss: 0.388621
# [260]	valid_0's multi_logloss: 0.387141
# [262]	valid_0's multi_logloss: 0.386278
# [264]	valid_0's multi_logloss: 0.386814
# [266]	valid_0's multi_logloss: 0.386729
# [268]	valid_0's multi_logloss: 0.388535
# [270]	valid_0's multi_logloss: 0.386715
# [272]	valid_0's multi_logloss: 0.386907
# [274]	valid_0's multi_logloss: 0.382974
# [276]	valid_0's multi_logloss: 0.379645
# [278]	valid_0's multi_logloss: 0.378045
# [280]	valid_0's multi_logloss: 0.37777
# [282]	valid_0's multi_logloss: 0.379047
# [284]	valid_0's multi_logloss: 0.374426
# [286]	valid_0's multi_logloss: 0.375932
# [288]	valid_0's multi_logloss: 0.376015
# [290]	valid_0's multi_logloss: 0.373345
# [292]	valid_0's multi_logloss: 0.374614
# [294]	valid_0's multi_logloss: 0.373314
# [296]	valid_0's multi_logloss: 0.373656
# [298]	valid_0's multi_logloss: 0.369953
# [300]	valid_0's multi_logloss: 0.368675
# [302]	valid_0's multi_logloss: 0.370799
# [304]	valid_0's multi_logloss: 0.36992
# [306]	valid_0's multi_logloss: 0.367862
# [308]	valid_0's multi_logloss: 0.369049
# [310]	valid_0's multi_logloss: 0.371534
# [312]	valid_0's multi_logloss: 0.373295
# [314]	valid_0's multi_logloss: 0.374051
# [316]	valid_0's multi_logloss: 0.372703
# [318]	valid_0's multi_logloss: 0.372967
# [320]	valid_0's multi_logloss: 0.375781
# [322]	valid_0's multi_logloss: 0.374949
# [324]	valid_0's multi_logloss: 0.376189
# [326]	valid_0's multi_logloss: 0.376058
# [328]	valid_0's multi_logloss: 0.374703
# [330]	valid_0's multi_logloss: 0.375576
# [332]	valid_0's multi_logloss: 0.37652
# [334]	valid_0's multi_logloss: 0.377209
# [336]	valid_0's multi_logloss: 0.378418
# [338]	valid_0's multi_logloss: 0.377885
# [340]	valid_0's multi_logloss: 0.375849
# [342]	valid_0's multi_logloss: 0.371375
# [344]	valid_0's multi_logloss: 0.372022
# [346]	valid_0's multi_logloss: 0.370699
# [348]	valid_0's multi_logloss: 0.36973
# [350]	valid_0's multi_logloss: 0.370917
# [352]	valid_0's multi_logloss: 0.370856
# [354]	valid_0's multi_logloss: 0.372101
# [356]	valid_0's multi_logloss: 0.371216
# Early stopping, best iteration is:
# [307]	valid_0's multi_logloss: 0.367762
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=10000, n_jobs=-1, num_leaves=31, objective='binary',
#         random_state=None, reg_alpha=0.0, reg_lambda=1, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
y_pred = model.predict(X_test)
print(f1_score(y_pred=y_pred, y_true=y_test, average='macro'))
# Out:
# 0.8142857142857143

# %%
(n, bins, patches) = plt.hist(y_train, density=True, bins=range(5+1))
print('percentage per stage: ', n)
print('class_weight', 1/n)

y_pred = model.predict(X_test)
print(f1_score(y_pred=y_pred, y_true=y_test, average='macro'))

cnf_matrix_again = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cnf_matrix_again, ["0","1","2","3","4"])
plot_confusion_matrix(cnf_matrix_again, ["0","1","2","3","4"], normalize=True)
plt.show()
# Out:
# percentage per stage:  [0.09448901 0.03535499 0.44743787 0.14972955 0.27298858]
# class_weight [10.58324115 28.28455285  2.23494715  6.67870855  3.66315689]
# 0.8142857142857143

# %%
y_pred = model.predict(features_test)

# stages repartition in train set
nb_stages = len(np.unique(label_train))
print('number of different stages: ', nb_stages)
(n, bins, patches) = plt.hist(label_train, density=True, bins=range(nb_stages+1), fc=(0, 0.5, 1, 0.5))
print('percentage per stage train: ', n*100)
(n, bins, patches) = plt.hist(y_pred, density=True, bins=range(nb_stages+1), fc=(1, 0.5, 0, 0.5))
print('percentage per stage test: ', n*100)
plt.show()
# Out:
# number of different stages:  5
# percentage per stage train:  [ 9.45180078  3.53365196 44.74392123 14.96774531 27.30288072]
# percentage per stage test:  [ 9.31648815  1.04169449 49.82237773 10.5104303  29.30900932]

# %% [markdown]
# # Hyperparameter tuning

# %%
# CV on 20% of the whole dataset only

features, X_test, label, y_test = train_test_split(features_train, label_train, test_size=0.8, random_state=0)
print(features.shape, len(label))
# Out:
# (7657, 1366) 7657

# %%
random_grid = {'reg_lambda' : [0.1, 1, 5, 10, 15, 20],
               'class_weight': [None, 'balanced'],
               }

clf = lgb.LGBMClassifier(objective='binary',n_estimators=10000)
clf_random = RandomizedSearchCV(estimator = clf, scoring= 'f1_macro',
                               param_distributions = random_grid,
                               n_iter=12, cv=3,
                               verbose=6, random_state=0, n_jobs=1)

# Fit the random search model
clf_random.fit(features, label)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] reg_lambda=0.1, class_weight=None ...............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  reg_lambda=0.1, class_weight=None, score=0.6005663620682172, total=26.4min
# [CV] reg_lambda=0.1, class_weight=None ...............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 26.5min remaining:    0.0s
# [CV]  reg_lambda=0.1, class_weight=None, score=0.6284994940569816, total=33.3min
# [CV] reg_lambda=0.1, class_weight=None ...............................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 60.1min remaining:    0.0s
# [CV]  reg_lambda=0.1, class_weight=None, score=0.6216378318278561, total=44.0min
# [CV] reg_lambda=1, class_weight=None .................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 104.4min remaining:    0.0s
# [CV]  reg_lambda=1, class_weight=None, score=0.6079529866006124, total=46.8min
# [CV] reg_lambda=1, class_weight=None .................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 151.4min remaining:    0.0s

# %% [markdown]
# # Prepare for submission

# %%
res = {}
res["sleep_stage"] = y_pred
df = pd.DataFrame(res)
df.index.name = 'id'
df.head()
# Out:
#     sleep_stage
# id
# 0             2
# 1             0
# 2             2
# 3             4
# 4             4

# %%
y_pred[:100]
# Out:
# array([2, 0, 2, 4, 4, 2, 2, 3, 2, 3, 2, 2, 3, 2, 4, 4, 2, 4, 2, 2, 2, 2,
#        2, 4, 2, 4, 0, 4, 4, 2, 2, 4, 4, 2, 0, 2, 2, 2, 4, 4, 2, 2, 4, 3,
#        2, 2, 2, 2, 4, 2, 4, 0, 4, 2, 2, 4, 4, 0, 3, 2, 4, 4, 3, 2, 0, 2,
#        3, 0, 2, 4, 3, 2, 2, 4, 4, 3, 2, 3, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2,
#        2, 2, 4, 2, 0, 2, 2, 2, 4, 2, 4, 4])

# %%
df.to_csv('test_LGBMClassifier_train995.csv')
